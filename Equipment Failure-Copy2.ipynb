# %% [markdown]
# # Import datasets and libraries

# %%
import numpy as np
import pandas as pd
import os

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
train_df = pd.read_csv('equip_failures_training_set.csv')

# %%
# Replace string 'na' with NaN value
train_df = train_df.replace('na', np.nan)

# Coerce type to float to get rid of NaN problem
train_df = train_df.astype(float)
train_df['id'] = train_df['id'].astype(int)
train_df['target'] = train_df['target'].astype(int)

# %%
train_df = train_df.drop(['sensor68_measure','sensor40_measure','sensor41_measure',
               'sensor42_measure','sensor43_measure'], axis=1)

# %%
test_df = pd.read_csv('equip_failures_test_set.csv')
test_df = test_df.replace('na', np.nan)
test_df = test_df.astype(float)
test_df['id'] = test_df['id'].astype(int)

# %%
test_df = test_df.drop(['sensor68_measure','sensor40_measure','sensor41_measure',
               'sensor42_measure','sensor43_measure'], axis=1)

# %% [markdown]
# # Different Models

# %%
import lightgbm
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV

# %%
#Split train data in order to reserve %80 of train data for test.
data_train_y = train_df['target']
data_train_x = train_df.drop(['id','target'], axis=1)


from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(data_train_x,data_train_y,
                                                    test_size = 0.2,random_state=314)

# %%
def learning_rate_010_decay_power_099(current_iter):
    base_learning_rate = 0.1
    lr = base_learning_rate  * np.power(.99, current_iter)
    return lr if lr > 1e-3 else 1e-3

def learning_rate_010_decay_power_0995(current_iter):
    base_learning_rate = 0.1
    lr = base_learning_rate  * np.power(.995, current_iter)
    return lr if lr > 1e-3 else 1e-3

def learning_rate_005_decay_power_099(current_iter):
    base_learning_rate = 0.05
    lr = base_learning_rate  * np.power(.99, current_iter)
    return lr if lr > 1e-3 else 1e-3

# %%
fit_params={"early_stopping_rounds":30, 
            "eval_metric" : 'auc', 
            "eval_set" : [(x_test,y_test)],
            'eval_names': ['valid'],
            'verbose': 100,
            'categorical_feature': 'auto'}

# %%
from scipy.stats import randint as sp_randint
from scipy.stats import uniform as sp_uniform
param_test ={'num_leaves': sp_randint(6, 50), 
             'min_child_samples': sp_randint(100, 500), 
             'min_child_weight': [1e-5, 1e-3, 1e-2, 1e-1, 1, 1e1, 1e2, 1e3, 1e4],
             'subsample': sp_uniform(loc=0.2, scale=0.8), 
             'colsample_bytree': sp_uniform(loc=0.4, scale=0.6),
             'reg_alpha': [0, 1e-1, 1, 2, 5, 7, 10, 50, 100],
             'reg_lambda': [0, 1e-1, 1, 5, 10, 20, 50, 100]}

# %%
#This parameter defines the number of HP points to be tested
n_HP_points_to_test = 100

import lightgbm as lgb
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV

#n_estimators is set to a "large value". The actual number of trees build will depend on early stopping and 5000 define only the absolute maximum
clf = lgb.LGBMClassifier(max_depth=-1, random_state=314, silent=True, 
                         metric='None', n_jobs=4, n_estimators=5000)

gs = RandomizedSearchCV(
    estimator=clf, param_distributions=param_test, 
    n_iter=n_HP_points_to_test,
    scoring='roc_auc',
    cv=10,
    refit=True,
    random_state=314,
    verbose=True)

# %%
gs.fit(x_train, y_train, **fit_params)
print('Best score reached: {} with params: {} '.format(gs.best_score_, gs.best_params_))
# Out:
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.984229
# Early stopping, best iteration is:
# [144]	valid's auc: 0.985548
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.981619
# [200]	valid's auc: 0.984299
# [300]	valid's auc: 0.985777
# Early stopping, best iteration is:
# [351]	valid's auc: 0.986049
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.984508
# [200]	valid's auc: 0.98608
# [300]	valid's auc: 0.986566
# Early stopping, best iteration is:
# [299]	valid's auc: 0.986604
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.984086
# Early stopping, best iteration is:
# [162]	valid's auc: 0.985233
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.984634
# [200]	valid's auc: 0.986504
# [300]	valid's auc: 0.987419
# Early stopping, best iteration is:
# [333]	valid's auc: 0.987703
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [38]	valid's auc: 0.981251
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.984247
# [200]	valid's auc: 0.985975
# Early stopping, best iteration is:
# [251]	valid's auc: 0.986501
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.983859
# [200]	valid's auc: 0.985334
# [300]	valid's auc: 0.986153
# Early stopping, best iteration is:
# [368]	valid's auc: 0.986446
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.985101
# [200]	valid's auc: 0.986594
# Early stopping, best iteration is:
# [258]	valid's auc: 0.986786
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [37]	valid's auc: 0.982162
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.984143
# [200]	valid's auc: 0.986272
# [300]	valid's auc: 0.986642
# Early stopping, best iteration is:
# [278]	valid's auc: 0.986714
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [49]	valid's auc: 0.982339
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.986036
# [200]	valid's auc: 0.98756
# [300]	valid's auc: 0.987997
# Early stopping, best iteration is:
# [279]	valid's auc: 0.98805
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [31]	valid's auc: 0.982571
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.985559
# [200]	valid's auc: 0.987733
# [300]	valid's auc: 0.98818
# [400]	valid's auc: 0.988615
# Early stopping, best iteration is:
# [414]	valid's auc: 0.988703
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [34]	valid's auc: 0.981505
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.984971
# [200]	valid's auc: 0.986754
# [300]	valid's auc: 0.987368
# [400]	valid's auc: 0.987755
# Early stopping, best iteration is:
# [395]	valid's auc: 0.987757
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.984171
# [200]	valid's auc: 0.985574
# [300]	valid's auc: 0.98629
# [400]	valid's auc: 0.986629
# Early stopping, best iteration is:
# [413]	valid's auc: 0.986653
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [35]	valid's auc: 0.982106
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [56]	valid's auc: 0.983418
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.977177
# Early stopping, best iteration is:
# [70]	valid's auc: 0.977258
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [29]	valid's auc: 0.976078
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [38]	valid's auc: 0.97764
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [37]	valid's auc: 0.979731
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [33]	valid's auc: 0.978578
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [67]	valid's auc: 0.976736
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [55]	valid's auc: 0.977038
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [17]	valid's auc: 0.976743
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [30]	valid's auc: 0.97642
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [33]	valid's auc: 0.97654
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.987832
# Early stopping, best iteration is:
# [106]	valid's auc: 0.988338
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.987091
# Early stopping, best iteration is:
# [82]	valid's auc: 0.988041
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.988256
# Early stopping, best iteration is:
# [142]	valid's auc: 0.989064
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.983865
# Early stopping, best iteration is:
# [71]	valid's auc: 0.985307
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.986388
# Early stopping, best iteration is:
# [77]	valid's auc: 0.987688
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.985954
# Early stopping, best iteration is:
# [82]	valid's auc: 0.986407
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [64]	valid's auc: 0.986649
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.98645
# Early stopping, best iteration is:
# [120]	valid's auc: 0.988412
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.989611
# Early stopping, best iteration is:
# [97]	valid's auc: 0.989963
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.986965
# Early stopping, best iteration is:
# [80]	valid's auc: 0.988194
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.986752
# Early stopping, best iteration is:
# [73]	valid's auc: 0.987395
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.986889
# Early stopping, best iteration is:
# [102]	valid's auc: 0.98716
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.989147
# Early stopping, best iteration is:
# [107]	valid's auc: 0.989277
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [56]	valid's auc: 0.987736
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.987849
# Early stopping, best iteration is:
# [91]	valid's auc: 0.988213
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.983856
# Early stopping, best iteration is:
# [87]	valid's auc: 0.984446
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.987653
# Early stopping, best iteration is:
# [88]	valid's auc: 0.988412
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.986407
# Early stopping, best iteration is:
# [91]	valid's auc: 0.986623
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.988352
# Early stopping, best iteration is:
# [133]	valid's auc: 0.989247
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.987088
# Early stopping, best iteration is:
# [137]	valid's auc: 0.987629
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.986018
# Early stopping, best iteration is:
# [76]	valid's auc: 0.986783
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [58]	valid's auc: 0.98621
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.987715
# Early stopping, best iteration is:
# [86]	valid's auc: 0.988278
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [57]	valid's auc: 0.985991
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [57]	valid's auc: 0.988058
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [68]	valid's auc: 0.986195
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [61]	valid's auc: 0.986924
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.986036
# Early stopping, best iteration is:
# [147]	valid's auc: 0.986737
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.985891
# Early stopping, best iteration is:
# [74]	valid's auc: 0.986279
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [55]	valid's auc: 0.987527
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [35]	valid's auc: 0.985586
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [46]	valid's auc: 0.985906
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.989671
# Early stopping, best iteration is:
# [86]	valid's auc: 0.989764
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [51]	valid's auc: 0.985943
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [66]	valid's auc: 0.988424
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [62]	valid's auc: 0.986695
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [35]	valid's auc: 0.987517
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.983839
# Early stopping, best iteration is:
# [80]	valid's auc: 0.984869
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.987964
# Early stopping, best iteration is:
# [125]	valid's auc: 0.989055
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.984929
# Early stopping, best iteration is:
# [78]	valid's auc: 0.985998
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.98897
# Early stopping, best iteration is:
# [92]	valid's auc: 0.989241
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.98661
# Early stopping, best iteration is:
# [71]	valid's auc: 0.987474
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.990594
# Early stopping, best iteration is:
# [87]	valid's auc: 0.990882
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.985945
# Early stopping, best iteration is:
# [75]	valid's auc: 0.987222
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.987332
# Early stopping, best iteration is:
# [79]	valid's auc: 0.988048
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.984056
# Early stopping, best iteration is:
# [81]	valid's auc: 0.985183
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.987313
# Early stopping, best iteration is:
# [72]	valid's auc: 0.987803
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.988317
# Early stopping, best iteration is:
# [88]	valid's auc: 0.988906
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [52]	valid's auc: 0.986712
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.986571
# Early stopping, best iteration is:
# [72]	valid's auc: 0.9874
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.985482
# Early stopping, best iteration is:
# [166]	valid's auc: 0.986424
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [33]	valid's auc: 0.982542
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.986078
# Early stopping, best iteration is:
# [134]	valid's auc: 0.986743
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.985261
# Early stopping, best iteration is:
# [153]	valid's auc: 0.985915
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.986056
# [200]	valid's auc: 0.986733
# Early stopping, best iteration is:
# [230]	valid's auc: 0.986975
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.985188
# [200]	valid's auc: 0.986601
# Early stopping, best iteration is:
# [211]	valid's auc: 0.986751
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.98634
# [200]	valid's auc: 0.987061
# Early stopping, best iteration is:
# [212]	valid's auc: 0.987269
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.984701
# [200]	valid's auc: 0.985447
# Early stopping, best iteration is:
# [193]	valid's auc: 0.985621
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.986917
# Early stopping, best iteration is:
# [149]	valid's auc: 0.987889
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.986031
# Early stopping, best iteration is:
# [165]	valid's auc: 0.986684
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.985555
# Early stopping, best iteration is:
# [129]	valid's auc: 0.985982
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.985054
# [200]	valid's auc: 0.986082
# Early stopping, best iteration is:
# [227]	valid's auc: 0.986269
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [30]	valid's auc: 0.984196
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [54]	valid's auc: 0.986565
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.985717
# [200]	valid's auc: 0.986132
# Early stopping, best iteration is:
# [176]	valid's auc: 0.986597
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.985537
# Early stopping, best iteration is:
# [93]	valid's auc: 0.985783
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.986695
# Early stopping, best iteration is:
# [129]	valid's auc: 0.987022
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.986791
# Early stopping, best iteration is:
# [97]	valid's auc: 0.986871
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.986919
# Early stopping, best iteration is:
# [85]	valid's auc: 0.987225
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.985451
# Early stopping, best iteration is:
# [137]	valid's auc: 0.985911
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.987541
# Early stopping, best iteration is:
# [148]	valid's auc: 0.988564
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.986913
# Early stopping, best iteration is:
# [73]	valid's auc: 0.987377
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.989331
# Early stopping, best iteration is:
# [159]	valid's auc: 0.990441
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.987231
# Early stopping, best iteration is:
# [82]	valid's auc: 0.987545
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.988269
# Early stopping, best iteration is:
# [146]	valid's auc: 0.989263
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.986519
# Early stopping, best iteration is:
# [164]	valid's auc: 0.988266
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.988444
# Early stopping, best iteration is:
# [123]	valid's auc: 0.988715
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.987882
# Early stopping, best iteration is:
# [133]	valid's auc: 0.988128
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.988318
# Early stopping, best iteration is:
# [136]	valid's auc: 0.988876
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.987769
# Early stopping, best iteration is:
# [88]	valid's auc: 0.988167
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.984898
# Early stopping, best iteration is:
# [148]	valid's auc: 0.985864
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.982779
# [200]	valid's auc: 0.985637
# [300]	valid's auc: 0.986727
# [400]	valid's auc: 0.98703
# Early stopping, best iteration is:
# [379]	valid's auc: 0.9872
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.98606
# [200]	valid's auc: 0.98711
# [300]	valid's auc: 0.98828
# [400]	valid's auc: 0.988914
# Early stopping, best iteration is:
# [468]	valid's auc: 0.989502
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.984544
# [200]	valid's auc: 0.986066
# Early stopping, best iteration is:
# [221]	valid's auc: 0.986482
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.986019
# [200]	valid's auc: 0.987244
# [300]	valid's auc: 0.988129
# [400]	valid's auc: 0.98832
# Early stopping, best iteration is:
# [375]	valid's auc: 0.988418
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.983042
# [200]	valid's auc: 0.98443
# Early stopping, best iteration is:
# [259]	valid's auc: 0.985002
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.986136
# [200]	valid's auc: 0.986421
# Early stopping, best iteration is:
# [170]	valid's auc: 0.986882
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.983638
# Early stopping, best iteration is:
# [125]	valid's auc: 0.984473
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [32]	valid's auc: 0.979781
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.98494
# [200]	valid's auc: 0.986406
# [300]	valid's auc: 0.987359
# Early stopping, best iteration is:
# [275]	valid's auc: 0.987477
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.98349
# Early stopping, best iteration is:
# [70]	valid's auc: 0.983887
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.98311
# Early stopping, best iteration is:
# [70]	valid's auc: 0.983903
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.984917
# Early stopping, best iteration is:
# [120]	valid's auc: 0.985079
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.983931
# [200]	valid's auc: 0.98627
# Early stopping, best iteration is:
# [207]	valid's auc: 0.986377
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.985546
# [200]	valid's auc: 0.986793
# [300]	valid's auc: 0.987316
# Early stopping, best iteration is:
# [296]	valid's auc: 0.987481
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [56]	valid's auc: 0.984078
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.985285
# [200]	valid's auc: 0.986202
# [300]	valid's auc: 0.986975
# [400]	valid's auc: 0.987316
# [500]	valid's auc: 0.987584
# [600]	valid's auc: 0.987769
# [700]	valid's auc: 0.98799
# [800]	valid's auc: 0.988135
# [900]	valid's auc: 0.98827
# Early stopping, best iteration is:
# [915]	valid's auc: 0.988296
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.984507
# Early stopping, best iteration is:
# [85]	valid's auc: 0.984706
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.984831
# Early stopping, best iteration is:
# [97]	valid's auc: 0.984949
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.984535
# Early stopping, best iteration is:
# [160]	valid's auc: 0.984927
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.985918
# Early stopping, best iteration is:
# [128]	valid's auc: 0.987415
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [45]	valid's auc: 0.983551
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.987323
# [200]	valid's auc: 0.988806
# Early stopping, best iteration is:
# [185]	valid's auc: 0.989002
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [29]	valid's auc: 0.983808
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.9867
# Early stopping, best iteration is:
# [152]	valid's auc: 0.987487
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.98682
# Early stopping, best iteration is:
# [135]	valid's auc: 0.987068
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.985946
# Early stopping, best iteration is:
# [149]	valid's auc: 0.987194
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.985878
# [200]	valid's auc: 0.987163
# Early stopping, best iteration is:
# [206]	valid's auc: 0.987272
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.986995
# Early stopping, best iteration is:
# [157]	valid's auc: 0.98766
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.98694
# Early stopping, best iteration is:
# [131]	valid's auc: 0.987439
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [59]	valid's auc: 0.984487
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [51]	valid's auc: 0.982808
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [50]	valid's auc: 0.983418
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.98443
# Early stopping, best iteration is:
# [95]	valid's auc: 0.98443
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [57]	valid's auc: 0.983998
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.983105
# Early stopping, best iteration is:
# [88]	valid's auc: 0.983105
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.98339
# Early stopping, best iteration is:
# [97]	valid's auc: 0.983396
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [44]	valid's auc: 0.983621
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [57]	valid's auc: 0.985269
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.981756
# Early stopping, best iteration is:
# [88]	valid's auc: 0.981756
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [68]	valid's auc: 0.988248
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.986699
# Early stopping, best iteration is:
# [97]	valid's auc: 0.986848
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [60]	valid's auc: 0.989331
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [49]	valid's auc: 0.986084
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [51]	valid's auc: 0.987426
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [62]	valid's auc: 0.98788
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [54]	valid's auc: 0.987129
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.986965
# Early stopping, best iteration is:
# [81]	valid's auc: 0.98733
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [65]	valid's auc: 0.989045
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [57]	valid's auc: 0.988305
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [43]	valid's auc: 0.977861
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [15]	valid's auc: 0.977057
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [45]	valid's auc: 0.978425
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [46]	valid's auc: 0.978047
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [32]	valid's auc: 0.977937
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [69]	valid's auc: 0.976809
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [44]	valid's auc: 0.979573
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [65]	valid's auc: 0.97906
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [47]	valid's auc: 0.978822
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [33]	valid's auc: 0.97751
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.986184
# Early stopping, best iteration is:
# [137]	valid's auc: 0.986893
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.987534
# Early stopping, best iteration is:
# [125]	valid's auc: 0.988355
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.989508
# Early stopping, best iteration is:
# [105]	valid's auc: 0.989681
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [61]	valid's auc: 0.984912
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.988864
# Early stopping, best iteration is:
# [81]	valid's auc: 0.989631
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [62]	valid's auc: 0.985438
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.988748
# Early stopping, best iteration is:
# [120]	valid's auc: 0.989163
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.986498
# Early stopping, best iteration is:
# [139]	valid's auc: 0.98759
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [63]	valid's auc: 0.98735
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [63]	valid's auc: 0.987724
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.979737
# Early stopping, best iteration is:
# [82]	valid's auc: 0.979744
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.979348
# Early stopping, best iteration is:
# [75]	valid's auc: 0.979362
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.979561
# Early stopping, best iteration is:
# [94]	valid's auc: 0.97957
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.979982
# Early stopping, best iteration is:
# [75]	valid's auc: 0.979986
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.979391
# Early stopping, best iteration is:
# [74]	valid's auc: 0.979414
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.978971
# Early stopping, best iteration is:
# [78]	valid's auc: 0.978974
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.979338
# Early stopping, best iteration is:
# [73]	valid's auc: 0.979545
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.979961
# Early stopping, best iteration is:
# [84]	valid's auc: 0.979983
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.979453
# Early stopping, best iteration is:
# [75]	valid's auc: 0.979457
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.979406
# Early stopping, best iteration is:
# [76]	valid's auc: 0.979414
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.985638
# [200]	valid's auc: 0.98803
# Early stopping, best iteration is:
# [230]	valid's auc: 0.988093
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.985859
# [200]	valid's auc: 0.988338
# Early stopping, best iteration is:
# [249]	valid's auc: 0.988719
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.986701
# [200]	valid's auc: 0.98855
# Early stopping, best iteration is:
# [234]	valid's auc: 0.989019
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.985605
# Early stopping, best iteration is:
# [152]	valid's auc: 0.987767
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.986988
# [200]	valid's auc: 0.988436
# Early stopping, best iteration is:
# [198]	valid's auc: 0.988481
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.984934
# [200]	valid's auc: 0.988065
# Early stopping, best iteration is:
# [213]	valid's auc: 0.988298
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.986592
# [200]	valid's auc: 0.987662
# Early stopping, best iteration is:
# [248]	valid's auc: 0.988149
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.984794
# [200]	valid's auc: 0.986772
# Early stopping, best iteration is:
# [244]	valid's auc: 0.987481
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.986951
# [200]	valid's auc: 0.988669
# Early stopping, best iteration is:
# [250]	valid's auc: 0.989258
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.985454
# [200]	valid's auc: 0.987856
# Early stopping, best iteration is:
# [214]	valid's auc: 0.988028
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.984978
# Early stopping, best iteration is:
# [137]	valid's auc: 0.985665
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [43]	valid's auc: 0.983693
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.986799
# Early stopping, best iteration is:
# [168]	valid's auc: 0.987735
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.986522
# Early stopping, best iteration is:
# [89]	valid's auc: 0.9868
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.986353
# Early stopping, best iteration is:
# [166]	valid's auc: 0.987185
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.985813
# Early stopping, best iteration is:
# [129]	valid's auc: 0.986051
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.985466
# Early stopping, best iteration is:
# [131]	valid's auc: 0.985799
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.985743
# Early stopping, best iteration is:
# [105]	valid's auc: 0.985831
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.987096
# Early stopping, best iteration is:
# [151]	valid's auc: 0.987629
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [41]	valid's auc: 0.985089
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [40]	valid's auc: 0.986081
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.985837
# Early stopping, best iteration is:
# [86]	valid's auc: 0.98593
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.988475
# Early stopping, best iteration is:
# [118]	valid's auc: 0.988947
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.985772
# Early stopping, best iteration is:
# [77]	valid's auc: 0.986587
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [41]	valid's auc: 0.985865
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [64]	valid's auc: 0.98547
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.987747
# Early stopping, best iteration is:
# [79]	valid's auc: 0.988077
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [55]	valid's auc: 0.985166
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.988047
# Early stopping, best iteration is:
# [86]	valid's auc: 0.988417
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [36]	valid's auc: 0.986645
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.986555
# [200]	valid's auc: 0.98794
# Early stopping, best iteration is:
# [254]	valid's auc: 0.988401
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.9839
# [200]	valid's auc: 0.98616
# [300]	valid's auc: 0.987302
# Early stopping, best iteration is:
# [329]	valid's auc: 0.987471
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.986467
# Early stopping, best iteration is:
# [106]	valid's auc: 0.987096
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.98683
# [200]	valid's auc: 0.988328
# Early stopping, best iteration is:
# [170]	valid's auc: 0.988481
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.987043
# [200]	valid's auc: 0.988348
# [300]	valid's auc: 0.989339
# Early stopping, best iteration is:
# [292]	valid's auc: 0.989357
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.984584
# [200]	valid's auc: 0.986929
# [300]	valid's auc: 0.987965
# Early stopping, best iteration is:
# [305]	valid's auc: 0.988061
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.987279
# Early stopping, best iteration is:
# [144]	valid's auc: 0.98796
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.98523
# Early stopping, best iteration is:
# [87]	valid's auc: 0.985463
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.98595
# Early stopping, best iteration is:
# [115]	valid's auc: 0.986773
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.985632
# [200]	valid's auc: 0.987958
# Early stopping, best iteration is:
# [226]	valid's auc: 0.988438
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.987264
# Early stopping, best iteration is:
# [144]	valid's auc: 0.987655
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [60]	valid's auc: 0.984627
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.985932
# [200]	valid's auc: 0.987103
# [300]	valid's auc: 0.988195
# [400]	valid's auc: 0.988744
# [500]	valid's auc: 0.98902
# Early stopping, best iteration is:
# [501]	valid's auc: 0.989021
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.985148
# [200]	valid's auc: 0.987202
# Early stopping, best iteration is:
# [207]	valid's auc: 0.987276
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.987759
# Early stopping, best iteration is:
# [139]	valid's auc: 0.988472
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.984306
# Early stopping, best iteration is:
# [160]	valid's auc: 0.985391
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.985851
# [200]	valid's auc: 0.98769
# [300]	valid's auc: 0.988123
# Early stopping, best iteration is:
# [330]	valid's auc: 0.988372
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.985819
# [200]	valid's auc: 0.9868
# Early stopping, best iteration is:
# [223]	valid's auc: 0.987083
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.986502
# [200]	valid's auc: 0.987611
# [300]	valid's auc: 0.988354
# Early stopping, best iteration is:
# [324]	valid's auc: 0.988519
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.985831
# Early stopping, best iteration is:
# [148]	valid's auc: 0.98683
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.982564
# Early stopping, best iteration is:
# [131]	valid's auc: 0.982757
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.980209
# Early stopping, best iteration is:
# [73]	valid's auc: 0.980379
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.983474
# Early stopping, best iteration is:
# [133]	valid's auc: 0.983765
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [66]	valid's auc: 0.981776
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.98271
# Early stopping, best iteration is:
# [109]	valid's auc: 0.982876
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.980638
# Early stopping, best iteration is:
# [142]	valid's auc: 0.981349
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.981866
# Early stopping, best iteration is:
# [144]	valid's auc: 0.982007
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.981722
# Early stopping, best iteration is:
# [152]	valid's auc: 0.982072
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.980869
# Early stopping, best iteration is:
# [84]	valid's auc: 0.981323
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.98102
# Early stopping, best iteration is:
# [134]	valid's auc: 0.981666
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [21]	valid's auc: 0.977287
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [22]	valid's auc: 0.97738
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [61]	valid's auc: 0.978582
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [57]	valid's auc: 0.980001
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [23]	valid's auc: 0.976641
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [52]	valid's auc: 0.979048
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [20]	valid's auc: 0.977267
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [35]	valid's auc: 0.980008
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [27]	valid's auc: 0.976683
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [32]	valid's auc: 0.976559
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.984694
# [200]	valid's auc: 0.986661
# Early stopping, best iteration is:
# [188]	valid's auc: 0.987009
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.985459
# Early stopping, best iteration is:
# [84]	valid's auc: 0.986042
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.988758
# [200]	valid's auc: 0.990331
# Early stopping, best iteration is:
# [180]	valid's auc: 0.990409
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.986971
# Early stopping, best iteration is:
# [81]	valid's auc: 0.987201
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.986511
# [200]	valid's auc: 0.987056
# Early stopping, best iteration is:
# [174]	valid's auc: 0.987579
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.9855
# Early stopping, best iteration is:
# [94]	valid's auc: 0.985778
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.987392
# Early stopping, best iteration is:
# [78]	valid's auc: 0.987779
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.987396
# Early stopping, best iteration is:
# [136]	valid's auc: 0.988245
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.987354
# Early stopping, best iteration is:
# [124]	valid's auc: 0.988643
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.98579
# Early stopping, best iteration is:
# [112]	valid's auc: 0.986142
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.986292
# Early stopping, best iteration is:
# [117]	valid's auc: 0.986541
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.983818
# Early stopping, best iteration is:
# [98]	valid's auc: 0.983841
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.987583
# Early stopping, best iteration is:
# [108]	valid's auc: 0.987618
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.986669
# Early stopping, best iteration is:
# [101]	valid's auc: 0.986694
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.986678
# Early stopping, best iteration is:
# [109]	valid's auc: 0.986822
# Training until validation scores don't improve for 30 rounds.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-40-bc9cfae2897f> in <module>
# ----> 1 gs.fit(x_train, y_train, **fit_params)
#       2 print('Best score reached: {} with params: {} '.format(gs.best_score_, gs.best_params_))
#
# ~\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     720                 return results_container[0]
#     721
# --> 722             self._run_search(evaluate_candidates)
#     723
#     724         results = results_container[0]
#
# ~\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py in _run_search(self, evaluate_candidates)
#    1513         evaluate_candidates(ParameterSampler(
#    1514             self.param_distributions, self.n_iter,
# -> 1515             random_state=self.random_state))
#
# ~\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py in evaluate_candidates(candidate_params)
#     709                                for parameters, (train, test)
#     710                                in product(candidate_params,
# --> 711                                           cv.split(X, y, groups)))
#     712
#     713                 all_candidate_params.extend(candidate_params)
#
# ~\Anaconda3\lib\site-packages\sklearn\externals\joblib\parallel.py in __call__(self, iterable)
#     918                 self._iterating = self._original_iterator is not None
#     919
# --> 920             while self.dispatch_one_batch(iterator):
#     921                 pass
#     922
#
# ~\Anaconda3\lib\site-packages\sklearn\externals\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     757                 return False
#     758             else:
# --> 759                 self._dispatch(tasks)
#     760                 return True
#     761
#
# ~\Anaconda3\lib\site-packages\sklearn\externals\joblib\parallel.py in _dispatch(self, batch)
#     714         with self._lock:
#     715             job_idx = len(self._jobs)
# --> 716             job = self._backend.apply_async(batch, callback=cb)
#     717             # A job can complete so quickly than its callback is
#     718             # called before we get here, causing self._jobs to
#
# ~\Anaconda3\lib\site-packages\sklearn\externals\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     180     def apply_async(self, func, callback=None):
#     181         """Schedule a func to be run"""
# --> 182         result = ImmediateResult(func)
#     183         if callback:
#     184             callback(result)
#
# ~\Anaconda3\lib\site-packages\sklearn\externals\joblib\_parallel_backends.py in __init__(self, batch)
#     547         # Don't delay the application, to avoid keeping the input
#     548         # arguments in memory
# --> 549         self.results = batch()
#     550
#     551     def get(self):
#
# ~\Anaconda3\lib\site-packages\sklearn\externals\joblib\parallel.py in __call__(self)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# ~\Anaconda3\lib\site-packages\sklearn\externals\joblib\parallel.py in <listcomp>(.0)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# ~\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, error_score)
#     526             estimator.fit(X_train, **fit_params)
#     527         else:
# --> 528             estimator.fit(X_train, y_train, **fit_params)
#     529
#     530     except Exception as e:
#
# ~\Anaconda3\lib\site-packages\lightgbm\sklearn.py in fit(self, X, y, sample_weight, init_score, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_metric, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks)
#     742                                         verbose=verbose, feature_name=feature_name,
#     743                                         categorical_feature=categorical_feature,
# --> 744                                         callbacks=callbacks)
#     745         return self
#     746
#
# ~\Anaconda3\lib\site-packages\lightgbm\sklearn.py in fit(self, X, y, sample_weight, init_score, group, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_group, eval_metric, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks)
#     542                               verbose_eval=verbose, feature_name=feature_name,
#     543                               categorical_feature=categorical_feature,
# --> 544                               callbacks=callbacks)
#     545
#     546         if evals_result:
#
# ~\Anaconda3\lib\site-packages\lightgbm\engine.py in train(params, train_set, num_boost_round, valid_sets, valid_names, fobj, feval, init_model, feature_name, categorical_feature, early_stopping_rounds, evals_result, verbose_eval, learning_rates, keep_training_booster, callbacks)
#     216                                     evaluation_result_list=None))
#     217
# --> 218         booster.update(fobj=fobj)
#     219
#     220         evaluation_result_list = []
#
# ~\Anaconda3\lib\site-packages\lightgbm\basic.py in update(self, train_set, fobj)
#    1800             _safe_call(_LIB.LGBM_BoosterUpdateOneIter(
#    1801                 self.handle,
# -> 1802                 ctypes.byref(is_finished)))
#    1803             self.__is_predicted_cur_iter = [False for _ in range_(self.__num_dataset)]
#    1804             return is_finished.value == 1
#
# KeyboardInterrupt:

# %%
opt_parameters = {'application': 'binary',
                  'objective': 'binary',
                  'colsample_bytree': 0.4211627356071123, 
                  'min_child_samples': 371, 
                  'min_child_weight': 0.001, 
                  'num_leaves': 15, 
                  'reg_alpha': 1, 
                  'reg_lambda': 0.1, 
                  'subsample': 0.9518946967698729}

# %%
#Configure locally from hardcoded values
clf_final = lgb.LGBMClassifier(**clf.get_params())
#set optimal parameters
clf_final.set_params(**opt_parameters)

#Train the final model with learning rate decay
clf_final.fit(x_train, y_train, **fit_params, 
              callbacks=[lgb.reset_parameter(learning_rate=learning_rate_010_decay_power_0995)])
# Out:
# LGBMClassifier(application='binary', boosting_type='gbdt', class_weight=None,
#         colsample_bytree=0.4211627356071123, importance_type='split',
#         learning_rate=0.1, max_depth=-1, metric='None',
#         min_child_samples=371, min_child_weight=0.001, min_split_gain=0.0,
#         n_estimators=5000, n_jobs=4, num_leaves=15, objective='binary',
#         random_state=314, reg_alpha=1, reg_lambda=0.1, silent=True,
#         subsample=0.9518946967698729, subsample_for_bin=200000,
#         subsample_freq=0)
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.987745
# Early stopping, best iteration is:
# [76]	valid's auc: 0.988559
# LGBMClassifier(application='binary', boosting_type='gbdt', class_weight=None,
#         colsample_bytree=0.4211627356071123, importance_type='split',
#         learning_rate=0.1, max_depth=-1, metric='None',
#         min_child_samples=371, min_child_weight=0.001, min_split_gain=0.0,
#         n_estimators=5000, n_jobs=4, num_leaves=15, objective='binary',
#         random_state=314, reg_alpha=1, reg_lambda=0.1, silent=True,
#         subsample=0.9518946967698729, subsample_for_bin=200000,
#         subsample_freq=0)

# %%
probabilities = clf_final.predict(test_df.drop(['id'], axis=1))

# %%
#probabilities = clf_final.predict(test_df.drop(['id'], axis=1))
submission = pd.DataFrame({
    'id': test_df['id'],
    'target': probabilities})

submission.to_csv("submission.csv", index=False)
